# %%
import sys
import os
import inspect
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pywt import threshold, wavedec, Wavelet, waverec
import math

sys.path.append(os.getcwd()+'/../scripts/')
from Preprocessing import Preprocessing

plt.rcParams["figure.figsize"]=40,20
plt.rcParams.update({'font.size': 28})
# %load_ext autoreload

# %%
# %autoreload 2

# %%
data = pd.read_csv('../data/data_final.csv', index_col=0)
pre = Preprocessing()

# %%
abs_data = data[data.columns[13:]]
qua_data = data[data.columns[:13]]

# %%
def plot(data):
    fig, ax = plt.subplots()
    if data.ndim == 1:
        a = plt.plot(data)
    else:
        a = plt.plot(data.columns, data.T)
    
    plt.xticks([])
    plt.title('Absorbance x Wavelength')
    plt.xlabel('Wavelength')
    plt.ylabel('Absorbance')

# %%
plot(abs_data.iloc[:7])

# %% [markdown]
# # mean centering

# %%
mean_centered_arr = pre.mean_center(abs_data.values)
mean_centered_df = pd.DataFrame(data=mean_centered_arr, index=np.arange(828), columns=abs_data.columns)

# %%
plot(mean_centered_df.iloc[:7])

# %% [markdown]
# # moving average

# %%
mov_windows = [5, 7, 9, 11]
d_order = [1, 2]
d_windows = [5, 7, 9, 11]
norms = [pre.msc, pre.snv]
pre_treated = data.copy()

for mov_window in mov_windows:
    smoothed = pre.moving_average(mean_centered_df.values, mov_window)
    for order in d_order:
        for d_window in d_windows:
            derivated = pre.sav_gol_derivative(smoothed, order, 2, d_window)
            for norm in norms:
                normalized = norm(derivated)
                pre_treated[abs_data.columns] = normalized
                pre_treated.to_csv('../data/pretreated/movavg%s_deriv%sw%s_norm%s.csv' % \
                                   (mov_window, order, d_window, norm.__name__))

# %% [markdown]
# # savitzky golay

# %%
sav_windows = [5, 7, 9, 11]
d_order = [1, 2]
d_windows = [5, 7, 9, 11]
norms = [pre.msc, pre.snv]

for sav_window in sav_windows:
    smoothed = pre.sav_gol(mean_centered_df.values, 2, sav_window)
    for order in d_order:
        for d_window in d_windows:
            derivated = pre.sav_gol_derivative(smoothed, order, 2, d_window)
            for norm in norms:
                normalized = norm(derivated)
                pre_treated[abs_data.columns] = normalized
                pre_treated.to_csv('../data/pretreated/savavg%s_deriv%sw%s_norm%s.csv' % \
                                   (sav_window, order, d_window, norm.__name__))

# %% [markdown]
# # wavelet

# %%
wnames = ['db3', 'db4']
levels = [2, 3, 4]
d_order = [1, 2]
d_windows = [5, 7, 9, 11]
norms = [pre.msc, pre.snv]

for wname in wnames:
    for level in levels:
        smoothed = pre.wavelet_denoising(mean_centered_df.values, wname, level)
        for order in d_order:
            for d_window in d_windows:
                derivated = pre.sav_gol_derivative(smoothed, order, 2, d_window)
                for norm in norms:
                    normalized = norm(derivated)
                    pre_treated.to_csv('../data/pretreated/wav%sl%s_deriv%sw%s_norm%s.csv' % \
                                       (wname, level, order, d_window, norm.__name__))
# Out:
# /home/danielesreis/.local/lib/python3.6/site-packages/pywt/_thresholding.py:23: RuntimeWarning: invalid value encountered in true_divide
#   thresholded = (1 - value/magnitude)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-818261549fad> in <module>
#      12                 derivated = pre.sav_gol_derivative(smoothed, order, 2, d_window)
#      13                 for norm in norms:
# ---> 14                     normalized = norm(derivated)
#      15                     pre_treated[abs_data.columns] = normalized
#      16                     pre_treated.to_csv('../data/pretreated/not_mean_centered/wav%sl%s_deriv%sw%s_norm%s.csv' % \
#
# ~/Projects/pibic-2018/notebooks/../scripts/Preprocessing.py in msc(self, data)
#     117
#     118                 mean            = np.mean(data, axis=0)
# --> 119                 coeffs          = np.apply_along_axis(fit_reg_line, 1, data, mean)
#     120                 new_data        = apply_correction(coeffs)
#     121
#
# ~/.local/lib/python3.6/site-packages/numpy/lib/shape_base.py in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     355     except StopIteration:
#     356         raise ValueError('Cannot apply_along_axis when any iteration dimensions are 0')
# --> 357     res = asanyarray(func1d(inarr_view[ind0], *args, **kwargs))
#     358
#     359     # build a buffer for storing evaluations of func1d.
#
# ~/Projects/pibic-2018/notebooks/../scripts/Preprocessing.py in fit_reg_line(row, mean)
#     106
#     107                 def fit_reg_line(row, mean):
# --> 108                         return np.polyfit(mean, row, 1)
#     109
#     110                 def apply_correction(coeffs):
#
# ~/.local/lib/python3.6/site-packages/numpy/lib/polynomial.py in polyfit(x, y, deg, rcond, full, w, cov)
#     578     scale = NX.sqrt((lhs*lhs).sum(axis=0))
#     579     lhs /= scale
# --> 580     c, resids, rank, s = lstsq(lhs, rhs, rcond)
#     581     c = (c.T/scale).T  # broadcast scale coefficients
#     582
#
# ~/.local/lib/python3.6/site-packages/numpy/linalg/linalg.py in lstsq(a, b, rcond)
#    2154     signature = 'DDd->Ddid' if isComplexType(t) else 'ddd->ddid'
#    2155     extobj = get_linalg_error_extobj(_raise_linalgerror_lstsq)
# -> 2156     x, resids, rank, s = gufunc(a, b, rcond, signature=signature, extobj=extobj)
#    2157
#    2158     # remove the axis we added
#
# ValueError: On entry to DLASCL parameter number 4 had an illegal value
